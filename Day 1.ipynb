# %%
a=1,2,3,4
print(a)
# Out:
# (1, 2, 3, 4)

# %%
name = "madhan"
print(name)
# Out:
# madhan

# %%
a=10
b=20
sum = a+b;
print(sum);
# Out:
# 30

# %%
pi=3.14
print(type(pi))
# Out:
# <class 'float'>

# %%
greeting="hello"
print(greeting[0])
# Out:
# h

# %%
class car:
    color = "red"
    my_car=car()
    print(my_car.color)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 class car:
#       2     color = "red"
#       3     my_car=car()
#
# Cell In[6], line 3, in car()
#       1 class car:
#       2     color = "red"
# ----> 3     my_car=car()
#       4     print(my_car.color)
#
# NameError: name 'car' is not defined

# %%
class student:
    name="Alice"
s=student()
print(s.name)
s.name="bob"
print(s.name)
# Out:
# Alice
# bob
